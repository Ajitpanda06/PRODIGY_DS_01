# %% [markdown]
# # Import the Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Collection & Processing

# %%
# Skip the first 4 rows (adjust as needed)
data = pd.read_csv("C:/Users/ajit/Ajit/MAIN FILE DATA SCIENCE/PRODIGY INFOTECH INTERNSHIP/World Bank Population Dataset/API_SP.POP.TOTL_DS2_en_csv_v2_85.csv", skiprows=4)

# %%
# printing the first 5 rows of the data frame
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2014         2015         2016         2017  \
# ...

# %%
# printing the last 5 rows of the  data frame
data.tail()
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    947000.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5542459.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16520441.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3119430.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3806310.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261    966000.0    994000.0   1022000.0   1050000.0   1078000.0  ...
# 262   5646668.0   5753386.0   5860197.0   5973803.0   6097298.0  ...
# 263  16989464.0  17503133.0  18042215.0  18603097.0  19187194.0  ...
# 264   3219451.0   3323427.0   3431381.0   3542764.0   3658024.0  ...
# 265   3925952.0   4049778.0   4177931.0   4310332.0   4447149.0  ...
#
#            2014        2015        2016        2017        2018        2019  \
# ...

# %%
# Number of rows and columns 
data.shape
# Out:
# (266, 68)

# %%
# getting some information about the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Data columns (total 68 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    266 non-null    object
#  1   Country Code    266 non-null    object
#  2   Indicator Name  266 non-null    object
#  3   Indicator Code  266 non-null    object
#  4   1960            264 non-null    float64
#  5   1961            264 non-null    float64
#  6   1962            264 non-null    float64
#  7   1963            264 non-null    float64
#  8   1964            264 non-null    float64
#  9   1965            264 non-null    float64
#  10  1966            264 non-null    float64
#  11  1967            264 non-null    float64
#  12  1968            264 non-null    float64
#  13  1969            264 non-null    float64
#  14  1970            264 non-null    float64
#  15  1971            264 non-null    float64
#  16  1972            264 non-null    float64
# ...

# %%
# Check the number of missing value 
data.isnull().sum()
# Out:
# Country Name        0
# Country Code        0
# Indicator Name      0
# Indicator Code      0
# 1960                2
#                  ...
# 2019                1
# 2020                1
# 2021                1
# 2022                1
# Unnamed: 67       266
# Length: 68, dtype: int64

# %%
# For demonstration, let's create a sample DataFrame
data = pd.DataFrame({
    'Gender': ['Male', 'Female', 'Male', 'Female', 'Male', 'Female', 'Male', 'Male', 'Female', 'Female'],
    'Count': [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
})

# %%
# Group the data by 'Gender' and calculate the sum of counts
gender_counts = data.groupby('Gender')['Count'].sum()

# %%
# Plot the bar chart
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color=['blue', 'pink'])
plt.title('Distribution of Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Sample data (ages)
ages = [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]

# Plot histogram
plt.hist(ages, bins=5, color='skyblue', edgecolor='black')
plt.title('Distribution of Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
# Sample data (ages)
ages = [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]

# Plot box plot
sns.boxplot(x=ages, color='skyblue')
plt.title('Box Plot of Ages')
plt.xlabel('Age')
plt.show()

# %%
# Sample data (genders)
genders = ['Male', 'Female']
counts = [60, 40]

# Plot pie chart
plt.pie(counts, labels=genders, colors=['blue', 'pink'], autopct='%1.1f%%')
plt.title('Distribution of Genders')
plt.show()

# %%
# Sample data (heights and weights)
heights = [160, 165, 170, 175, 180]
weights = [60, 65, 70, 75, 80]

# Plot scatter plot
plt.scatter(heights, weights, color='skyblue')
plt.title('Scatter Plot of Heights vs Weights')
plt.xlabel('Height (cm)')
plt.ylabel('Weight (kg)')
plt.show()

# %%
# Sample correlation matrix
corr_matrix = np.array([[1.0, 0.5, -0.3],
                        [0.5, 1.0, 0.7],
                        [-0.3, 0.7, 1.0]])

# Plot heatmap
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', square=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
# Define the years from 1960 to 2022
years = list(range(1960, 2023))

# Sample population data (replace it with your actual population data)
# For demonstration, let's assume a linearly increasing population
population = [100 + i * 5 for i in range(len(years))]  # Replace this with your actual population data

# Plot the line plot
plt.plot(years, population, marker='o', color='skyblue')
plt.title('Population Trend')
plt.xlabel('Year')
plt.ylabel('Population (millions)')
plt.xticks(range(1960, 2023, 10))  # Show every 10 years on the x-axis
plt.grid(True)
plt.show()

# %%
# Sample data (synthetic dataframe)
data = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [5, 4, 3, 2, 1],
    'C': [3, 3, 3, 3, 3]
})

# Plot pair plot
sns.pairplot(data)
plt.title('Pairwise Scatter Plot')
plt.show()

# %%
# Sample data (categories and counts)
categories = ['Category 1', 'Category 2']
counts_male = [30, 20]
counts_female = [20, 30]

# Plot stacked bar chart
plt.bar(categories, counts_male, color='blue', label='Male')
plt.bar(categories, counts_female, bottom=counts_male, color='pink', label='Female')
plt.title('Distribution of Categories by Gender')
plt.xlabel('Category')
plt.ylabel('Count')
plt.legend()
plt.show()

# %%
population = [100 + (year - 1960) * 5 for year in years]  # Replace this with your actual population data

# Plot the area chart
plt.fill_between(years, population, color='skyblue', alpha=0.4)
plt.plot(years, population, color='skyblue', alpha=0.6)
plt.title('Population Trend')
plt.xlabel('Year')
plt.ylabel('Population (millions)')
plt.xticks(range(1960, 2023, 10))  # Show every 10 years on the x-axis
plt.grid(True)
plt.show()
